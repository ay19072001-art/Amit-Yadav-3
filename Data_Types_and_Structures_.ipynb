# %% [markdown]
# 1. What are data structures, and why are they important?
#
#     Data Structures are organized ways of storing and managing data. They are important because they help in efficient data access, modification, for making programms faster.
#
# 2. Explain the difference between mutable and immutable data types with   examples.
#
#     Mutable can be changed and editable after creation. For Ex: List= [1,2,3] to List[10]
#
#     Immutable means that a data  type cannot be changed after they created. for Ex: string = "hello" → You can’t change "h" directly.
#
# 3. What are the main differences between lists and tuples in Python?
#
#     Lists and Tuples both are used to store data  but theirs are one common difference of between them ie Lists (Symbol[]) are mutable or changable but Tuples (Symbol ()) nature are immutable and cannot be changed.
#
# 4. Describe how dictionaries store data.
#
#     Dictionaries store data as key value pairs using hashing and each have location and key is unique.
#
# 5.  Why might you use a set instead of a list in Python?
#
#     In list there are not have duplicate entries so it would easy to check and data accuracy .
#
#
# 6.  What is a string in Python, and how is it different from a list?
#
#     String is sequence of characters and that can't be changed after creation . And list store multiple data type and can be changed after created.
#
# 7. How do tuples ensure data integrity in Python?
#
#     As we know tuples nature are immutable, so the data cannot be changed after creation, so we ensure the data integrity.
#
#
# 8. What is a hash table, and how does it relate to dictionaries in Python?
#
#     Yes hash table stores data using hash functions and it will be easy to fast access
#
# 9.  Can lists contain different data types in Python?
#
#     Yes a list can store multiple data types either its string, boolean, integer, float.
#
# 10.  Explain why strings are immutable in Python.
#
#     Strings are immutable for security, data authenticity, memory optimization, performance.
#
# 11. What advantages do dictionaries offer over lists for certain tasks?
#
#     Fast lookup using keys, Clear mapping between key and value, Better for structured data.
#
# 12. Describe a scenario where using a tuple would be preferable over a list.
#
#     Tuples are used which place their the things and scenario are fixed for example Week days (monday, tuesday etc), and days in a month which are fixed.
#
# 13. How do sets handle duplicate values in Python?
#
#     Sets automatically remove duplicate value.
#
# 14. How does the "IN" keyword work differently for lists and dictionaries?
#
#     "IN' functions are different in list and dictionaries :-
#
#
#              List= Check if an elements exists.
#              Dictionary  = check if a key exists.
#
# 15. Can you modify the elements of a tuple? Explain why or why not.
#
#     No, tuples elements can't be modified because tuples nature are immutable.
#
# 16. What is a nested dictionary, and give an example of its use case.
#
#     Nested dictionary means inside a particular dictionary. for Ex
#
#     student = { "name ": " AMAN", "details": {"Age": 20, "city":"Delhi"}}
#
# 17. Describe the time complexity of accessing elements in a dictionary.
#
#     Average: O(1) (constant time).
#
#     Worst case: O(n) (rare, due to hash collisions).
#
# 18. In what situations are lists preferred over dictionaries?
#
#     Lists data systmetic manner and also store duplicate values but dictionaries not.
#
# 19. Why are dictionaries considered unordered, and how does that affect data retrieval?
#
#     They are based on hasing, so order wasn't guaranteed. Retrieval depends on keys, not order.
#
# 20. Explain the difference between a list and a dictionary in terms of data retrieval.
#
#     List: Retrieve by index (position).
#
#     Dictionary: Retrieve by key (mapping).

# %% [markdown]
# Practical Questions

# %%
# 1 . Write a code to create a string with your name and print it.

name = "Amit Yadav"
print(name)
# Out:
# Amit Yadav

# %%
# 2. Write a code to find the length of the string "Hello World".

print(len("Hello World"))
# Out:
# 11

# %%
# 3. Write a code to slice the first 3 characters from the string " Python Programmiung"

String = "python programming"
print(String[:3])
# Out:
# pyt

# %%
# 4. write a code to convert the string "hello" to uppercase.

s = "hello"
print(s.upper())
# Out:
# HELLO

# %%
# 5. Write a code to replace the word "apple" with "orange" in the string "I Like apple".

s = "I like apple"
print(s. replace("apple","orange"))
# Out:
# I like orange

# %%
# 6. Write a code to create a list with number 1 to 5 and print it.

l1 = [1,2,3,4,5]
print(l1)
# Out:
# [1, 2, 3, 4, 5]

# %%
# 7. Write a code to append the number 10 to the list [1,2,3,4].
list2  =[1,2,3,4,5]
list2.append(10)
print(list2)
# Out:
# [1, 2, 3, 4, 5, 10]

# %%
# 8. Write a code to remove the number 3 from the list [1,2,3,4,5]
l1= [1,2,3,4,5]
l1.remove(3)
print(l1)
# Out:
# [1, 2, 4, 5]

# %%
# 9. Write a code to access the second element in the list['a','b','c','d']
print(['a','b','c','d'][1])
# Out:
# b

# %%
# 10. Write a code to reverse the list[10,20,30,40,50]
l3= [10,20,30,40,50]
l3.reverse()
print(l3)
# Out:
# [50, 40, 30, 20, 10]

# %%
# 11. Write a code to create a tuple with the elements 100, 200, 300 and print it.

t1 = (100,200,300)
print(t1)
# Out:
# (100, 200, 300)

# %%
# 12. Write a code to access the second-to-last element of the tuple ('red', 'green', 'blue', 'yellow').

t2= ('red', 'green', 'blue', 'yellow')
print(t2[-2])
# Out:
# blue

# %%
# 13. Write a code to find the minimum number in the tuple (10, 20, 5, 15).

t4= (10,20,5,15)
print(min(t4))
# Out:
# 5

# %%
# 14. Write a code to find the index of the element "cat" in the tuple ('dog', 'cat', 'rabbit').

t5 = ('dog', 'cat', 'rabbit')
print(t5.index("cat"))
# Out:
# 1

# %%
# 15. Write a code to create a tuple containing three different fruits and check if "kiwi" is in it.
fruits = ("apple","mango","orange")
print("kiwi" in fruits)
# Out:
# False

# %%
# 16. Write a code to create a set with the elements 'a', 'b', 'c' and print it.

set={'a','b','c'}
print(set)
# Out:
# {'a', 'c', 'b'}

# %%
# 17. Write a code to clear all elements from the set {1, 2, 3, 4, 5}.

set1 = {1,2,3,4,5}
set1.clear()
set1
# Out:
# set()

# %%
# 18. Write a code to remove the element 4 from the set {1, 2, 3, 4}.
set2 = {1,2,3,4,5}
set2.remove(4)
print(set2)
# Out:
# {1, 2, 3, 5}

# %%
# 19. Write a code to find the union of two sets {1, 2, 3} and {3, 4, 5}.
s1 = {1, 2, 3}
s2 = {3, 4, 5}
print(s1.union(s2))
# Out:
# {1, 2, 3, 4, 5}

# %%
# 20. Write a code to find the intersection of two sets {1, 2, 3} and {2, 3, 4}.
s1 = {1, 2, 3}
s2 = {2, 3, 4}
print(s1.intersection(s2))
# Out:
# {2, 3}

# %%
# 21. Write a code to create a dictionary with the keys "name", "age", and "city", and print it.
d = {"name":"Amit","age":20,"city":"Delhi"}
print(d)
# Out:
# {'name': 'Amit', 'age': 20, 'city': 'Delhi'}

# %%
# 22. Write a code to add a new key-value pair "country": "USA" to the dictionary {'name': 'John', 'age': 25}.
d = {"name":"Amit","age":20}
d["country"] = "USA"
print(d)
# Out:
# {'name': 'Amit', 'age': 20, 'country': 'USA'}

# %%
# 23. Write a code to access the value associated with the key "name" in the dictionary {'name': 'Alice', 'age': 30}.
d3 = {'name': 'Alice', 'age': 30}
print(d3["name"])
# Out:
# Alice

# %%
#24. Write a code to remove the key "age" from the dictionary {'name': 'Bob', 'age': 22, 'city': 'New York'}.
d4 = {'name': 'Bob', 'age': 22, 'city': 'New York'}
d4.pop( "age")
print(d4)
# Out:
# {'name': 'Bob', 'city': 'New York'}

# %%
# 25. Write a code to check if the key "city" exists in the dictionary {'name': 'Alice', 'city': 'Paris'}.
d5= {'name': 'Alice', 'city': 'Paris'}
print("city" in {'name':'Alice','city':'Paris'})
# Out:
# True

# %%
# 26. Write a code to create a list, a tuple, and a dictionary, and print them all.
l1 = [1,2,3]
t1 = (1,2,3)
d1 = {"a":1,"b":2}
print(l1,t1,d1)
# Out:
# [1, 2, 3] (1, 2, 3) {'a': 1, 'b': 2}

# %%
# 27. Write a code to create a list of 5 random numbers between 1 and 100, sort it in ascending order, and print the result.(replaced)

l5=[44,55,66,77,99]
l5.sort() # sort the list in place
print(l5)
# Out:
# [44, 55, 66, 77, 99]

# %%
# 28. Write a code to create a list with strings and print the element at the third index.

l6 = ["a","b","c","d"]
print(l6[2])
# Out:
# c

# %%
# 29. Write a code to combine two dictionaries into one and print the result.

d3={1: 'a', 2: 'b', 3: 'c'}
d4= {4: 'd', 5: 'e', 6: 'f'}
d3.update(d4)
print(d3)
# Out:
# {1: 'a', 2: 'b', 3: 'c', 4: 'd', 5: 'e', 6: 'f'}

# %%
# 30. Write a code to convert a list of strings into a set.
l5=["a","b"]
set=l5
print(set)
# Out:
# ['a', 'b']
